# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np

# %%
data=pd.read_csv("MY2018_Fuel_Consumption_Ratings.csv")

# %%
#dataset
data.head(100)
# Out:
#     MODEL          MAKE  ... FUELCONSUMPTION_COMB_MPG CO2_Emissions
# 0    2018         ACURA  ...                       34           192
# 1    2018         ACURA  ...                       26           259
# 2    2018         ACURA  ...                       26           251
# 3    2018         ACURA  ...                       26           250
# 4    2018         ACURA  ...                       34           196
# 5    2018         ACURA  ...                       32           205
# 6    2018         ACURA  ...                       32           209
# 7    2018         ACURA  ...                       29           228
# 8    2018         ACURA  ...                       27           240
# 9    2018    ALFA ROMEO  ...                       34           197
# 10   2018    ALFA ROMEO  ...                       34           197
# 11   2018    ALFA ROMEO  ...                       32           205
# 12   2018    ALFA ROMEO  ...                       31           217
# ...

# %%
#Summarizing the data
data.describe()
# Out:
#         MODEL   ENGINESIZE  ...  FUELCONSUMPTION_COMB_MPG  CO2_Emissions
# count  1067.0  1067.000000  ...               1067.000000    1067.000000
# mean   2018.0     3.127741  ...                 27.563261     250.691659
# std       0.0     1.329637  ...                  7.082765      55.976137
# min    2018.0     1.000000  ...                 13.000000      96.000000
# 25%    2018.0     2.000000  ...                 23.000000     211.000000
# 50%    2018.0     3.000000  ...                 27.000000     246.000000
# 75%    2018.0     3.600000  ...                 31.000000     288.000000
# max    2018.0     8.000000  ...                 69.000000     522.000000
#
# [8 rows x 8 columns]

# %%
#selecting some features to explore more
data1=data[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2_Emissions']]
data1.head(100)
# Out:
#     ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2_Emissions
# 0          2.4          4                   8.2            192
# 1          3.5          6                  11.0            259
# 2          3.5          6                  10.7            251
# 3          3.5          6                  10.7            250
# 4          3.5          6                   8.4            196
# 5          2.4          4                   8.7            205
# 6          2.4          4                   8.9            209
# 7          3.5          6                   9.8            228
# 8          3.5          6                  10.3            240
# 9          1.8          4                   8.4            197
# 10         1.8          4                   8.4            197
# 11         2.0          4                   8.7            205
# 12         2.0          4                   9.2            217
# 13         2.9          6                  11.9            280
# ...

# %%
data1.hist(figsize=(20,20))
plt.show()

# %%
#Plotting these features vs Emission to see how lineaar is their realtion
plt.scatter(data1.CYLINDERS,data1.CO2_Emissions,color='black')
plt.xlabel("Cylinders")
plt.ylabel("Emission")
plt.show()

# %%
plt.scatter(data1.ENGINESIZE,data1.CO2_Emissions,color='black')
plt.xlabel("Engine Size")
plt.ylabel("Emission")
plt.show()

# %%
plt.scatter(data1.FUELCONSUMPTION_COMB,data1.CO2_Emissions,color='black')
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# # Multiple Regression Model

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
x = data1[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']]
y = data1['CO2_Emissions']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)
classifier = xgb.sklearn.XGBClassifier(nthread=-1, seed=1)
classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=-1, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1,
#               silent=None, subsample=1, verbosity=1)

# %%
from sklearn.metrics import r2_score, explained_variance_score, mean_absolute_error
import seaborn as sns
predictions = classifier.predict(X_test)
print(f'R^2 score: {r2_score(y_true=y_test, y_pred=predictions):.2f}')
print(f'MAE score: {mean_absolute_error(y_true=y_test, y_pred=predictions):.2f}')
print(f'EVS score: {explained_variance_score(y_true=y_test, y_pred=predictions):.2f}')
rp = sns.regplot(x=y_test, y=predictions)
# Out:
# R^2 score: 0.96
# MAE score: 3.25
# EVS score: 0.96

# %%
import pickle
with open('Co2_emission.pkl', 'wb') as file:
  pickle.dump(classifier, file)
